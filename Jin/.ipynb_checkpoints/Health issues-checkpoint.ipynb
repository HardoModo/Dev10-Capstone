# %% [markdown]
# ### Health Status of child
# * Average weight and  income corelation*
# * Weight and continent corelation

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns

# %%
df = pd.read_csv('data/Child malnutrition.csv')

# %%
df.head(5)
# Out:
#   ISO code  Sex  Age  Height  Weight Continent           World Bank  Wasting  \
# 0      AFG    1    2      93      16      Asia           Low Income     18.2
# 1      AFG    1    4      97      15      Asia           Low Income      8.6
# 2      AFG    0    4      90      12      Asia           Low Income      9.5
# 3      ALB    0    2      78      16    Europe  Upper Middle Income      8.1
# 4      ALB    0    4      99      13    Europe  Upper Middle Income     12.2
#
#    Overweight  Stunting  ...  Unnamed: 1014 Unnamed: 1015  Unnamed: 1016  \
# 0         6.5      53.2  ...            NaN           NaN            NaN
# 1         4.6      59.3  ...            NaN           NaN            NaN
# 2         5.4      40.9  ...            NaN           NaN            NaN
# 3         9.5      20.4  ...            NaN           NaN            NaN
# 4        30.0      39.2  ...            NaN           NaN            NaN
#
#    Unnamed: 1017  Unnamed: 1018  Unnamed: 1019  Unnamed: 1020  Unnamed: 1021  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    Unnamed: 1022  Unnamed: 1023
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 1024 columns]

# %%
df.columns
# Out:
# Index(['ISO code', 'Sex', 'Age', 'Height', 'Weight', 'Continent', 'World Bank',
#        'Wasting', 'Overweight', 'Stunting',
#        ...
#        'Unnamed: 1014', 'Unnamed: 1015', 'Unnamed: 1016', 'Unnamed: 1017',
#        'Unnamed: 1018', 'Unnamed: 1019', 'Unnamed: 1020', 'Unnamed: 1021',
#        'Unnamed: 1022', 'Unnamed: 1023'],
#       dtype='object', length=1024)

# %%
column_counts = df['Overweight'].value_counts()

print(column_counts)
# Out:
# 4.9     13
# 4.7     13
# 4.0     12
# 6.2     11
# 1.6     11
#         ..
# 13.2     1
# 23.4     1
# 25.2     1
# 20.8     1
# 10.6     1
# Name: Overweight, Length: 175, dtype: int64

# %%
df['Overweight'] = df['Overweight'].astype(float)

# %%
df2 = df.groupby('World Bank')['Overweight'].mean().sort_values()
df2
# Out:
# World Bank
# Low Income             4.308609
# Lower Middle Income    6.026692
# High Income            8.050000
# Upper Middle Income    8.503518
# Name: Overweight, dtype: float64

# %%
plt.figure(figsize = (12, 12))
df2.plot(kind = 'barh')

plt.title("Child Average Weight Ratings By Income")

# %%
type(df2)

# %%
df3 = df.groupby('Continent')['Overweight'].mean().sort_values()
df3

# %%
plt.figure(figsize = (12, 12))
df3.plot(kind = 'barh')

plt.title("Child Average Weight Ratings By Continent")

# %% [markdown]
# ## 4 Major Health Issues in USA from 2004 to 2017

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as pl
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.tree import export_graphviz
from sklearn.datasets import load_iris

# %%
health_df = pd.read_csv('data/4healthissues.csv')

# %%
health_df.head(3)
# Out:
#   StateAbbr  2004+cardiovascular  2004+stroke  2004+obesity  2004+diabetes  \
# 0        ME                    6           17            29             38
# 1        NY                    6           13            27             32
# 2        NY                    3           16            31             37
#
#    2005+cardiovascular  2005+stroke  2005+obesity  2005+diabetes  \
# 0                   16           38            14             23
# 1                   15           35            15             19
# 2                    8           44            24             18
#
#    2006+cardiovascular  ...  2015+obesity  2015+diabetes  2016+cardiovascular  \
# 0                   23  ...            48             73                   38
# 1                   18  ...            46             63                   41
# 2                   19  ...            67             75                   33
#
#    2016+stroke  2016+obesity  2016+diabetes  2017+cardiovascular  2017+stroke  \
# 0           70            49             81                   37           83
# 1           47            49             77                   34           53
# 2           66            70             74                   24           71
#
#    2017+obesity  2017+diabetes
# 0            47             80
# 1            52             78
# 2            61             72
#
# [3 rows x 57 columns]

# %%
health_df.info(verbose=True)

# %%
health_df.columns
# Out:
# Index(['StateAbbr', '2004+cardiovascular', '2004+stroke', '2004+obesity',
#        '2004+diabetes', '2005+cardiovascular', '2005+stroke', '2005+obesity',
#        '2005+diabetes', '2006+cardiovascular', '2006+stroke', '2006+obesity',
#        '2006+diabetes', '2007+cardiovascular', '2007+stroke', '2007+obesity',
#        '2007+diabetes', '2008+cardiovascular', '2008+stroke', '2008+obesity',
#        '2008+diabetes', '2009+cardiovascular', '2009+stroke', '2009+obesity',
#        '2009+diabetes', '2010+cardiovascular', '2010+stroke', '2010+obesity',
#        '2010+diabetes', '2011+cardiovascular', '2011+stroke', '2011+obesity',
#        '2011+diabetes', '2012+cardiovascular', '2012+stroke', '2012+obesity',
#        '2012+diabetes', '2013+cardiovascular', '2013+stroke', '2013+obesity',
#        '2013+diabetes', '2014+cardiovascular', '2014+stroke', '2014+obesity',
#        '2014+diabetes', '2015+cardiovascular', '2015+stroke', '2015+obesity',
#        '2015+diabetes', '2016+cardiovascular', '2016+stroke', '2016+obesity',
#        '2016+diabetes', '2017+cardiovascular', '2017+stroke', '2017+obesity',
#        '2017+diabetes'],
#       dtype='object')

# %%
# column_names = health_df.columns.tolist()
# new_column_names = {col:col.replace('+', '_') for col in column_names}
# health_df = health_df.rename(columns=new_column_names)

# %%
column_names = health_df.columns.tolist()
new_column_names = {col: col.replace('+', '_') for col in column_names if col != 'StateAbbr'}
health_df = health_df.rename(columns=new_column_names)

# %%
health_df
# Out:
#     StateAbbr  2004_cardiovascular  2004_stroke  2004_obesity  2004_diabetes  \
# 0          ME                    6           17            29             38
# 1          NY                    6           13            27             32
# 2          NY                    3           16            31             37
# 3          GA                   14           14            29             31
# 4          PA                    7           16            30             37
# ..        ...                  ...          ...           ...            ...
# 205        CA                    5           13            38             27
# 206        CA                    4           17            29             35
# 207        CA                    7           13            33             34
# 208        CA                    4           22            41             24
# 209        WA                    6           17            30             46
#
#      2005_cardiovascular  2005_stroke  2005_obesity  2005_diabetes  \
# 0                     16           38            14             23
# 1                     15           35            15             19
# 2                      8           44            24             18
# 3                     25           48            23             22
# 4                     17           39            18             23
# ..                   ...          ...           ...            ...
# 205                   10           31            15             15
# 206                   13           45            19             23
# 207                   17           35            24             21
# 208                   10           45            38             19
# 209                   16           47            24             19
#
#      2006_cardiovascular  ...  2015_obesity  2015_diabetes  \
# 0                     23  ...            48             73
# 1                     18  ...            46             63
# 2                     19  ...            67             75
# 3                     24  ...            60             73
# 4                     24  ...            56             72
# ..                   ...  ...           ...            ...
# 205                   13  ...            56             57
# 206                   16  ...            58             73
# 207                   15  ...            58             65
# 208                   10  ...            60             66
# 209                   18  ...            66             68
#
#      2016_cardiovascular  2016_stroke  2016_obesity  2016_diabetes  \
# 0                     38           70            49             81
# 1                     41           47            49             77
# 2                     33           66            70             74
# 3                     59           65            51             78
# 4                     42           56            52             80
# ..                   ...          ...           ...            ...
# 205                   35           51            54             63
# 206                   38           57            48             75
# 207                   55           52            64             81
# 208                   36           67            63             75
# 209                   36           67            52             79
#
#      2017_cardiovascular  2017_stroke  2017_obesity  2017_diabetes
# 0                     37           83            47             80
# 1                     34           53            52             78
# 2                     24           71            61             72
# 3                     38           62            41             66
# 4                     35           61            56             78
# ..                   ...          ...           ...            ...
# 205                   24           60            53             63
# 206                   29           64            55             76
# 207                   42           61            63             77
# 208                   38           76            62             75
# 209                   33           77            53             73
#
# [210 rows x 57 columns]

# %%
health_df.describe()
# Out:
#        2004_cardiovascular  2004_stroke  2004_obesity  2004_diabetes  \
# count           210.000000   210.000000    210.000000     210.000000
# mean              7.433333    17.642857     34.261905      38.042857
# std               7.909647     8.135284     16.136765      10.017357
# min               0.000000     0.000000      0.000000       0.000000
# 25%               5.000000    14.000000     26.000000      33.000000
# 50%               6.000000    16.000000     32.000000      37.000000
# 75%               9.000000    18.000000     41.000000      42.000000
# max             100.000000   100.000000    100.000000     100.000000
#
#        2005_cardiovascular  2005_stroke  2005_obesity  2005_diabetes  \
# count           210.000000   210.000000    210.000000     210.000000
# mean             18.671429    44.619048     21.519048      23.238095
# std              14.289275    11.669189     10.511881       7.094743
# min               0.000000     0.000000      0.000000       0.000000
# 25%              12.000000    39.000000     16.000000      20.000000
# 50%              15.000000    44.000000     20.000000      22.000000
# 75%              20.000000    48.000000     26.000000      25.000000
# max             100.000000   100.000000    100.000000     100.000000
#
#        2006_cardiovascular  2006_stroke  ...  2015_obesity  2015_diabetes  \
# count           210.000000   210.000000  ...    210.000000     210.000000
# mean             21.557143    24.519048  ...     57.828571      71.957143
# std              11.451962     8.205035  ...     15.754369       9.505127
# min               0.000000     0.000000  ...      0.000000       0.000000
# 25%              16.000000    21.000000  ...     51.000000      68.000000
# 50%              20.000000    23.000000  ...     58.000000      72.000000
# 75%              24.750000    26.000000  ...     65.000000      76.000000
# max             100.000000   100.000000  ...    100.000000     100.000000
#
#        2016_cardiovascular  2016_stroke  2016_obesity  2016_diabetes  \
# count           210.000000   210.000000    210.000000     210.000000
# mean             45.728571    63.561905     51.761905      77.823810
# std              14.273730    10.137735     14.244632       8.494434
# min               0.000000     0.000000      0.000000       0.000000
# 25%              38.000000    58.000000     46.000000      74.000000
# 50%              44.000000    63.000000     51.000000      78.000000
# 75%              52.000000    69.000000     58.000000      81.750000
# max             100.000000   100.000000    100.000000     100.000000
#
#        2017_cardiovascular  2017_stroke  2017_obesity  2017_diabetes
# count           210.000000   210.000000    210.000000     210.000000
# mean             35.923810    70.838095     51.761905      77.309524
# std              12.521136    10.800606     13.846751       8.935409
# min               0.000000     0.000000      0.000000       0.000000
# 25%              29.000000    64.000000     45.250000      73.000000
# 50%              34.000000    71.000000     51.000000      78.000000
# 75%              41.000000    77.000000     58.000000      81.000000
# max             100.000000   100.000000    100.000000     100.000000
#
# [8 rows x 56 columns]

# %%
y = health_df['StateAbbr']
fig, ax = plt.subplots()

# %%
print(health_df.columns)
# Out:
# Index(['StateAbbr', '2004_cardiovascular', '2004_stroke', '2004_obesity',
#        '2004_diabetes', '2005_cardiovascular', '2005_stroke', '2005_obesity',
#        '2005_diabetes', '2006_cardiovascular', '2006_stroke', '2006_obesity',
#        '2006_diabetes', '2007_cardiovascular', '2007_stroke', '2007_obesity',
#        '2007_diabetes', '2008_cardiovascular', '2008_stroke', '2008_obesity',
#        '2008_diabetes', '2009_cardiovascular', '2009_stroke', '2009_obesity',
#        '2009_diabetes', '2010_cardiovascular', '2010_stroke', '2010_obesity',
#        '2010_diabetes', '2011_cardiovascular', '2011_stroke', '2011_obesity',
#        '2011_diabetes', '2012_cardiovascular', '2012_stroke', '2012_obesity',
#        '2012_diabetes', '2013_cardiovascular', '2013_stroke', '2013_obesity',
#        '2013_diabetes', '2014_cardiovascular', '2014_stroke', '2014_obesity',
#        '2014_diabetes', '2015_cardiovascular', '2015_stroke', '2015_obesity',
#        '2015_diabetes', '2016_cardiovascular', '2016_stroke', '2016_obesity',
#        '2016_diabetes', '2017_cardiovascular', '2017_stroke', '2017_obesity',
#        '2017_diabetes'],
#       dtype='object')

# %%
data = {}

# Replace this loop with your actual data source or calculation
for year in range(2004, 2018):
    for condition in ['obesity']:
        key = f'{year}_{condition}'
        value = ...  # Replace with your actual value calculation or data source
        data[key] = value

# %%
temp_df = pd.DataFrame([data])

# %%
temp_df = temp_df.transpose()

# %%
temp_df['Year'] = temp_df.index.str.split('_').str[0]

# %%
temp_df = temp_df.apply(pd.to_numeric, errors='coerce')

# %%
temp_df.plot(kind='bar', legend=False, figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Obesity by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# health_df['StateAbbr'].value_counts()

# %%
y = health_df['StateAbbr']
cols= [['2004_obesity'],['2008_obesity'],['2012_obesity'],['2014_obesity'],['2017_obesity']]
for col in cols:
    x= df[col]
    model = Linear
